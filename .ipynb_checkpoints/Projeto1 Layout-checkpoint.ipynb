# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 1

# %% [markdown]
#     LEONARDO IMAKUMA NEVES

# %% [markdown]
# ## TÍTULO DO SEU PROJETO

# %% [markdown]
# ___
# ## Introdução
#
# Descreva aqui o que pretende analisar!
#
# Capriche no português!!
# Se quiser pode utilizar pesquisas semelhantes publicadas em sites confiáveis!!

# %% [markdown]
# ___
# ## Análise e Resultados

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Leonardo\Documents\insper\ciencia dos dados

# %%
#Se usar o arquivo descompactado
#pd.read_csv('DOM2015.csv',sep=',')

#Se usar o arquivo compactado como está no dropbox púbico
#pd.read_csv('DOM2015csv.zip', compression='zip', header=0, sep=',', quotechar='"')

# %%
dados= pd.read_csv('DOM2009.csv',sep=',')

# %%
dadosID = dados[dados.UF == 27].loc[ : ,["UF","V0203","V0223","V0224","V0228","V0229","V4623","V4624","V2103","V2105","V2107","V2109","V2119 "]]

# %%
dadosCompletos=dadosID[pd.notnull(dadosID.V0203)]

# %%
dadosCompletos
# Out:
#        UF  V0203  V0223  V0224  V0228  V0229  V4623  V4624  V2103  V2105  \
# 46089  27    1.0    1.0    4.0    6.0    3.0    1.0    1.0    3.0    3.0
# 46090  27    1.0    1.0    4.0    4.0    3.0    2.0    1.0    1.0    3.0
# 46091  27    1.0    1.0    2.0    4.0    1.0    1.0    1.0    3.0    3.0
# 46092  27    1.0    1.0    2.0    4.0    1.0    1.0    1.0    3.0    3.0
# 46093  27    1.0    NaN    4.0    6.0    3.0    6.0    6.0    3.0    3.0
# 46094  27    1.0    1.0    2.0    4.0    3.0    1.0    1.0    3.0    3.0
# 46095  27    1.0    1.0    2.0    4.0    3.0    1.0    1.0    3.0    3.0
# 46096  27    1.0    1.0    4.0    4.0    3.0    1.0    1.0    3.0    3.0
# 46097  27    1.0    4.0    4.0    4.0    3.0    1.0    1.0    3.0    3.0
# 46098  27    1.0    1.0    2.0    4.0    3.0    2.0    1.0    3.0    3.0
# 46099  27    1.0    1.0    2.0    2.0    3.0    1.0    1.0    3.0    3.0
# 46101  27    1.0    1.0    2.0    4.0    3.0    1.0    1.0    3.0    3.0
# ...

# %%
dfc = dados.SENTIMENTO.value_counts()
dfc.plot(kind='bar', color=('pink', 'red','blue'), legend=False)

# %% [markdown]
# ___
# ## Conclusão

# %% [markdown]
# Descreva aqui suas conclusões!
